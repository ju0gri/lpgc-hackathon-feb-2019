# %%
import matplotlib.pyplot as plt
# %matplotlib notebook
import pandas as pd
df_history = pd.read_csv('cita_previa_historico.csv', delimiter=';')
df_history.describe()
# Out:
#                  ID  TIEMPO_MEDIO_ESPERA  ESPERAS_0_5  ESPERAS_5_10  \
# count  1.787000e+03          1787.000000  1787.000000   1787.000000
# mean   2.015592e+07            10.975263   307.011192     91.821489
# std    1.743737e+04            12.247189   155.370106     50.302779
# min    2.013010e+07             0.000000     0.000000      0.000000
# 25%    2.014070e+07             6.316883   235.500000     63.000000
# 50%    2.016011e+07             8.738833   331.000000     97.000000
# 75%    2.017071e+07            12.754038   414.000000    127.000000
# max    2.019020e+07           339.058883   717.000000    252.000000
#
#        ESPERAS_10_15  ESPERAS_15_30  ESPERAS_30_60  ESPERAS_60_MAS  \
# count    1787.000000    1787.000000    1787.000000     1787.000000
# mean       59.360381      90.003358      49.525462       12.703414
# std        35.645495      67.549020      66.685661       28.057260
# min         0.000000       0.000000       0.000000        0.000000
# ...

# %%
df_history
# Out:
#             ID        FECHA_MODIFICACION       FECHA  TIEMPO_MEDIO_ESPERA  \
# 0     20190130  2019-02-02T13:14:14.954Z  2019-01-30             6.807328
# 1     20190131  2019-02-02T13:14:14.954Z  2019-01-31             6.924776
# 2     20190201  2019-02-02T13:14:14.954Z  2019-02-01             7.661655
# 3     20190125  2019-02-02T13:14:14.953Z  2019-01-25             8.355622
# 4     20190126  2019-02-02T13:14:14.953Z  2019-01-26            19.641228
# 5     20190128  2019-02-02T13:14:14.953Z  2019-01-28             7.442576
# 6     20190129  2019-02-02T13:14:14.953Z  2019-01-29             5.766794
# 7     20190124  2019-02-02T13:14:14.882Z  2019-01-24             8.027324
# 8     20190117  2019-02-02T13:14:14.881Z  2019-01-17             8.752087
# 9     20190118  2019-02-02T13:14:14.881Z  2019-01-18            12.943775
# 10    20190119  2019-02-02T13:14:14.881Z  2019-01-19             8.314035
# 11    20190121  2019-02-02T13:14:14.881Z  2019-01-21             9.158364
# ...

# %%
from datetime import datetime
def convert_timestamp(date_field):
    if isinstance(date_field, str):
        return datetime.strptime(date_field, "%Y-%m-%d")
    else:
        return date_field.date()

# ID;FECHA_MODIFICACION;FECHA;
# TIEMPO_MEDIO_ESPERA;ESPERAS_0_5;ESPERAS_5_10;ESPERAS_10_15;ESPERAS_15_30;ESPERAS_30_60;ESPERAS_60_MAS;
# VISITAS_08_00_A_08_30;VISITAS_08_30_A_09_00;VISITAS_09_00_A_09_30;VISITAS_09_30_A_10_00;VISITAS_10_00_A_10_30;VISITAS_10_30_A_11_00;VISITAS_11_00_A_11_30;VISITAS_11_30_A_12_00;VISITAS_12_00_A_12_30;VISITAS_12_30_A_13_00;VISITAS_13_00_A_13_30;VISITAS_13_30_A_14_00;VISITAS_14_00_MAS;
# ENTREVISTAS_POR_DIA;ENTREVISTAS_08_00_A_08_30;ENTREVISTAS_08_30_A_09_00;ENTREVISTAS_09_00_A_09_30;ENTREVISTAS_09_30_A_10_00;ENTREVISTAS_10_00_A_10_30;ENTREVISTAS_10_30_A_11_00;ENTREVISTAS_11_00_A_11_30;ENTREVISTAS_11_30_A_12_00;ENTREVISTAS_12_00_A_12_30;ENTREVISTAS_12_30_A_13_00;ENTREVISTAS_13_00_A_13_30;ENTREVISTAS_13_30_A_14_00;ENTREVISTAS_14_00_MAS;uri
cleaned_history = pd.DataFrame({'id': df_history['ID'],
                               'date': df_history['FECHA'].apply(lambda x: convert_timestamp(x)),
                               'wait0-5' : df_history['ESPERAS_0_5'],
                               'wait5-10' : df_history['ESPERAS_5_10'], 
                               'wait15-30' :  df_history['ESPERAS_15_30'], 
                               'wait30-60' :  df_history['ESPERAS_30_60'], 
                               'wait60+' :  df_history['ESPERAS_60_MAS'],
                               'visit08:00-08:30': df_history['VISITAS_08_00_A_08_30'],
                               'visit08:30-09:00': df_history['VISITAS_08_30_A_09_00'],
                               'visit09:00-09:30': df_history['VISITAS_09_00_A_09_30'],
                               'visit09:30-10:00': df_history['VISITAS_09_30_A_10_00'],
                               'visit10:00-10:30': df_history['VISITAS_10_00_A_10_30'],
                               'visit10:30-11:00': df_history['VISITAS_10_30_A_11_00'],
                               'visit11:00-11:30': df_history['VISITAS_11_00_A_11_30'],
                               'visit11:30-12:00': df_history['VISITAS_11_30_A_12_00'],
                               'visit12:00-12:30': df_history['VISITAS_12_00_A_12_30'],
                               'visit12:30-13:00': df_history['VISITAS_12_30_A_13_00'],
                               'visit13:00-13:30': df_history['VISITAS_13_00_A_13_30'],
                               'visit13:30-14:00': df_history['VISITAS_13_30_A_14_00'],
                               'visit14:00+': df_history['VISITAS_14_00_MAS'],
                               'interviews_per_day': df_history['ENTREVISTAS_POR_DIA'],
                               'interview08:00-08:30': df_history['ENTREVISTAS_08_00_A_08_30'],
                               'interview08:30-09:00': df_history['ENTREVISTAS_08_30_A_09_00'],
                               'interview09:00-09:30': df_history['ENTREVISTAS_09_00_A_09_30'],
                               'interview09:30-10:00': df_history['ENTREVISTAS_09_30_A_10_00'],
                               'interview10:00-10:30': df_history['ENTREVISTAS_10_00_A_10_30'],
                               'interview10:30-11:00': df_history['ENTREVISTAS_10_30_A_11_00'],
                               'interview11:00-11:30': df_history['ENTREVISTAS_11_00_A_11_30'],
                               'interview11:30-12:00': df_history['ENTREVISTAS_11_30_A_12_00'],
                               'interview12:00-12:30': df_history['ENTREVISTAS_12_00_A_12_30'],
                               'interview12:30-13:00': df_history['ENTREVISTAS_12_30_A_13_00'],
                               'interview13:00-13:30': df_history['ENTREVISTAS_13_00_A_13_30'],
                               'interview13:30-14:00': df_history['ENTREVISTAS_13_30_A_14_00'],
                               'interview14:00+': df_history['ENTREVISTAS_14_00_MAS'],
                               'uri': df_history['uri']
                               })
cleaned_history
# Out:
#             id       date  wait0-5  wait5-10  wait15-30  wait30-60  wait60+  \
# 0     20190130 2019-01-30      372       105         57         15        3
# 1     20190131 2019-01-31      389        85         77         12        3
# 2     20190201 2019-02-01      343       148         84         19        1
# 3     20190125 2019-01-25      331        98         51         37        5
# 4     20190126 2019-01-26        5         5         19          6        0
# 5     20190128 2019-01-28      323        72        105         12        0
# 6     20190129 2019-01-29      394       142         51          8        1
# 7     20190124 2019-01-24      418       136         90         31        5
# 8     20190117 2019-01-17      345        94         69         18       10
# 9     20190118 2019-01-18      254        87        119         56       10
# 10    20190119 2019-01-19       18         9          7          2        0
# ...

# %%
cleaned_history['year'] = cleaned_history['date'].apply(lambda x: x.year)
cleaned_history['month'] = cleaned_history['date'].apply(lambda x: x.month)
cleaned_history['day'] = cleaned_history['date'].apply(lambda x: x.day)
cleaned_history['weekday'] = cleaned_history['date'].apply(lambda x: x.weekday())
cleaned_history
# Out:
#             id       date  wait0-5  wait5-10  wait15-30  wait30-60  wait60+  \
# 0     20190130 2019-01-30      372       105         57         15        3
# 1     20190131 2019-01-31      389        85         77         12        3
# 2     20190201 2019-02-01      343       148         84         19        1
# 3     20190125 2019-01-25      331        98         51         37        5
# 4     20190126 2019-01-26        5         5         19          6        0
# 5     20190128 2019-01-28      323        72        105         12        0
# 6     20190129 2019-01-29      394       142         51          8        1
# 7     20190124 2019-01-24      418       136         90         31        5
# 8     20190117 2019-01-17      345        94         69         18       10
# 9     20190118 2019-01-18      254        87        119         56       10
# 10    20190119 2019-01-19       18         9          7          2        0
# ...

# %%
from datetime import datetime
def convert_timestamp(date_field):
    if isinstance(date_field, str):
        return datetime.strptime(date_field, "%Y-%m-%d")
    else:
        return x.date()

waiting_time = pd.DataFrame({  'id': cleaned_history['id'],
                               'date': cleaned_history['date'],
                               'year': cleaned_history['year'],
                               'month': cleaned_history['month'],
                               'day': cleaned_history['day'],
                               'weekday': cleaned_history['weekday'],
                               '0-5' : cleaned_history['wait0-5'],
                               '5-10' : cleaned_history['wait5-10'], 
                               '15-30' :  cleaned_history['wait15-30'], 
                               '30-60' :  cleaned_history['wait30-60'], 
                               '60+' :  cleaned_history['wait60+']})
waiting_time
# Out:
#             id       date  year  month  day  weekday  0-5  5-10  15-30  30-60  \
# 0     20190130 2019-01-30  2019      1   30        2  372   105     57     15
# 1     20190131 2019-01-31  2019      1   31        3  389    85     77     12
# 2     20190201 2019-02-01  2019      2    1        4  343   148     84     19
# 3     20190125 2019-01-25  2019      1   25        4  331    98     51     37
# 4     20190126 2019-01-26  2019      1   26        5    5     5     19      6
# 5     20190128 2019-01-28  2019      1   28        0  323    72    105     12
# 6     20190129 2019-01-29  2019      1   29        1  394   142     51      8
# 7     20190124 2019-01-24  2019      1   24        3  418   136     90     31
# 8     20190117 2019-01-17  2019      1   17        3  345    94     69     18
# 9     20190118 2019-01-18  2019      1   18        4  254    87    119     56
# 10    20190119 2019-01-19  2019      1   19        5   18     9      7      2
# ...

# %%
df = pd.DataFrame({'year': waiting_time['year'],
                   '0-5' : waiting_time['0-5'],
                   '5-10' : waiting_time['5-10'], 
                   '15-30' :  waiting_time['15-30'], 
                   '30-60' :  waiting_time['30-60'], 
                   '60+' :  waiting_time['60+']})

df.groupby('year').sum().plot(kind="bar", stacked=True, figsize=(20,16))
plt.show()

# %%
df = pd.DataFrame({'month': waiting_time['month'],
                   '0-5' : waiting_time['0-5'],
                   '5-10' : waiting_time['5-10'], 
                   '15-30' :  waiting_time['15-30'], 
                   '30-60' :  waiting_time['30-60'], 
                   '60+' :  waiting_time['60+']})

df.groupby('month').sum().sort_values(by='month').plot(kind="bar", stacked=True, figsize=(20, 16))
plt.show()

# %%
df = pd.DataFrame({'weekday': waiting_time['weekday'],
                   '0-5' : waiting_time['0-5'],
                   '5-10' : waiting_time['5-10'], 
                   '15-30' :  waiting_time['15-30'], 
                   '30-60' :  waiting_time['30-60'], 
                   '60+' :  waiting_time['60+']})

df.groupby('weekday').sum().sort_values(by='weekday').plot(kind="bar", stacked=True, figsize=(20, 16))
plt.show()

# %%
visits = pd.DataFrame({'id': cleaned_history['id'],
                       'date': cleaned_history['date'],
                       'year': cleaned_history['year'],
                       'month': cleaned_history['month'],
                       'day': cleaned_history['day'],
                       'weekday': cleaned_history['weekday'],
                       'visits_per_day': cleaned_history['visit08:00-08:30'] + 
                                         cleaned_history['visit08:30-09:00'] +
                                         cleaned_history['visit09:00-09:30'] + 
                                         cleaned_history['visit09:30-10:00'] + 
                                         cleaned_history['visit10:00-10:30'] + 
                                         cleaned_history['visit10:30-11:00'] + 
                                         cleaned_history['visit11:00-11:30'] + 
                                         cleaned_history['visit11:30-12:00'] + 
                                         cleaned_history['visit12:00-12:30'] + 
                                         cleaned_history['visit12:30-13:00'] + 
                                         cleaned_history['visit13:30-14:00'],
                       '08:00-08:30': cleaned_history['visit08:00-08:30'],
                       '08:30-09:00': cleaned_history['visit08:30-09:00'],
                       '09:00-09:30': cleaned_history['visit09:00-09:30'],
                       '09:30-10:00': cleaned_history['visit09:30-10:00'],
                       '10:00-10:30': cleaned_history['visit10:00-10:30'],
                       '10:30-11:00': cleaned_history['visit10:30-11:00'],
                       '11:00-11:30': cleaned_history['visit11:00-11:30'],
                       '11:30-12:00': cleaned_history['visit11:30-12:00'],
                       '12:00-12:30': cleaned_history['visit12:00-12:30'],
                       '12:30-13:00': cleaned_history['visit12:30-13:00'],
                       '13:00-13:30': cleaned_history['visit13:00-13:30'],
                       '13:30-14:00': cleaned_history['visit13:30-14:00'],
                       '14:00+': cleaned_history['visit14:00+']
                      })
visits
# Out:
#             id       date  year  month  day  weekday  visits_per_day  \
# 0     20190130 2019-01-30  2019      1   30        2             614
# 1     20190131 2019-01-31  2019      1   31        3             571
# 2     20190201 2019-02-01  2019      2    1        4             678
# 3     20190125 2019-01-25  2019      1   25        4             568
# 4     20190126 2019-01-26  2019      1   26        5              39
# 5     20190128 2019-01-28  2019      1   28        0             534
# 6     20190129 2019-01-29  2019      1   29        1             627
# 7     20190124 2019-01-24  2019      1   24        3             689
# 8     20190117 2019-01-17  2019      1   17        3             550
# 9     20190118 2019-01-18  2019      1   18        4             553
# 10    20190119 2019-01-19  2019      1   19        5              38
# 11    20190121 2019-01-21  2019      1   21        0             537
# 12    20190122 2019-01-22  2019      1   22        1             616
# ...

# %%
df = pd.DataFrame({'year': visits['year'],
                   '08:00-08:30': visits['08:00-08:30'],
                   '08:30-09:00': visits['08:30-09:00'],
                   '09:00-09:30': visits['09:00-09:30'],
                   '09:30-10:00': visits['09:30-10:00'],
                   '10:00-10:30': visits['10:00-10:30'],
                   '10:30-11:00': visits['10:30-11:00'],
                   '11:00-11:30': visits['11:00-11:30'],
                   '11:30-12:00': visits['11:30-12:00'],
                   '12:00-12:30': visits['12:00-12:30'],
                   '12:30-13:00': visits['12:30-13:00'],
                   '13:00-13:30': visits['13:00-13:30'],
                   '13:30-14:00': visits['13:30-14:00'],
                   '14:00+': visits['14:00+']
                  })

df.groupby('year').sum().plot(kind="bar", stacked=True, figsize=(20,16))
plt.show()

# %%
df = pd.DataFrame({'month': visits['month'],
                   '08:00-08:30': visits['08:00-08:30'],
                   '08:30-09:00': visits['08:30-09:00'],
                   '09:00-09:30': visits['09:00-09:30'],
                   '09:30-10:00': visits['09:30-10:00'],
                   '10:00-10:30': visits['10:00-10:30'],
                   '10:30-11:00': visits['10:30-11:00'],
                   '11:00-11:30': visits['11:00-11:30'],
                   '11:30-12:00': visits['11:30-12:00'],
                   '12:00-12:30': visits['12:00-12:30'],
                   '12:30-13:00': visits['12:30-13:00'],
                   '13:00-13:30': visits['13:00-13:30'],
                   '13:30-14:00': visits['13:30-14:00'],
                   '14:00+': visits['14:00+']
                  })

df.groupby('month').sum().plot(kind="bar", stacked=True, figsize=(20,16))
plt.show()

# %%
df = pd.DataFrame({'weekday': visits['weekday'],
                   '08:00-08:30': visits['08:00-08:30'],
                   '08:30-09:00': visits['08:30-09:00'],
                   '09:00-09:30': visits['09:00-09:30'],
                   '09:30-10:00': visits['09:30-10:00'],
                   '10:00-10:30': visits['10:00-10:30'],
                   '10:30-11:00': visits['10:30-11:00'],
                   '11:00-11:30': visits['11:00-11:30'],
                   '11:30-12:00': visits['11:30-12:00'],
                   '12:00-12:30': visits['12:00-12:30'],
                   '12:30-13:00': visits['12:30-13:00'],
                   '13:00-13:30': visits['13:00-13:30'],
                   '13:30-14:00': visits['13:30-14:00'],
                   '14:00+': visits['14:00+']
                  })

df.groupby('weekday').sum().plot(kind="bar", stacked=True, figsize=(20,16))
plt.show()

# %%
interviews = pd.DataFrame({'id': cleaned_history['id'],
                       'date': cleaned_history['date'],
                       'year': cleaned_history['year'],
                       'month': cleaned_history['month'],
                       'day': cleaned_history['day'],
                       'weekday': cleaned_history['weekday'],
                       'interviews_per_day': cleaned_history['interviews_per_day'],
                       '08:00-08:30': cleaned_history['interview08:00-08:30'],
                       '08:30-09:00': cleaned_history['interview08:30-09:00'],
                       '09:00-09:30': cleaned_history['interview09:00-09:30'],
                       '09:30-10:00': cleaned_history['interview09:30-10:00'],
                       '10:00-10:30': cleaned_history['interview10:00-10:30'],
                       '10:30-11:00': cleaned_history['interview10:30-11:00'],
                       '11:00-11:30': cleaned_history['interview11:00-11:30'],
                       '11:30-12:00': cleaned_history['interview11:30-12:00'],
                       '12:00-12:30': cleaned_history['interview12:00-12:30'],
                       '12:30-13:00': cleaned_history['interview12:30-13:00'],
                       '13:00-13:30': cleaned_history['interview13:00-13:30'],
                       '13:30-14:00': cleaned_history['interview13:30-14:00'],
                       '14:00+': cleaned_history['interview14:00+'],
                      })
interviews
# Out:
#             id       date  year  month  day  weekday  interviews_per_day  \
# 0     20190130 2019-01-30  2019      1   30        2                 632
# 1     20190131 2019-01-31  2019      1   31        3                 634
# 2     20190201 2019-02-01  2019      2    1        4                 697
# 3     20190125 2019-01-25  2019      1   25        4                 591
# 4     20190126 2019-01-26  2019      1   26        5                  38
# 5     20190128 2019-01-28  2019      1   28        0                 551
# 6     20190129 2019-01-29  2019      1   29        1                 661
# 7     20190124 2019-01-24  2019      1   24        3                 776
# 8     20190117 2019-01-17  2019      1   17        3                 622
# 9     20190118 2019-01-18  2019      1   18        4                 578
# 10    20190119 2019-01-19  2019      1   19        5                  38
# 11    20190121 2019-01-21  2019      1   21        0                 551
# ...

# %%
df = pd.DataFrame({'year': waiting_time['year'],
                   '08:00-08:30': interviews['08:00-08:30'],
                   '08:30-09:00': interviews['08:30-09:00'],
                   '09:00-09:30': interviews['09:00-09:30'],
                   '09:30-10:00': interviews['09:30-10:00'],
                   '10:00-10:30': interviews['10:00-10:30'],
                   '10:30-11:00': interviews['10:30-11:00'],
                   '11:00-11:30': interviews['11:00-11:30'],
                   '11:30-12:00': interviews['11:30-12:00'],
                   '12:00-12:30': interviews['12:00-12:30'],
                   '12:30-13:00': interviews['12:30-13:00'],
                   '13:00-13:30': interviews['13:00-13:30'],
                   '13:30-14:00': interviews['13:30-14:00'],
                   '14:00+': interviews['14:00+'],
                   })

df.groupby('year').sum().sort_values(by='year').plot(kind="bar", stacked=True, figsize=(20, 16))
plt.show()

# %%
df = pd.DataFrame({'month': waiting_time['month'],
                   '08:00-08:30': interviews['08:00-08:30'],
                   '08:30-09:00': interviews['08:30-09:00'],
                   '09:00-09:30': interviews['09:00-09:30'],
                   '09:30-10:00': interviews['09:30-10:00'],
                   '10:00-10:30': interviews['10:00-10:30'],
                   '10:30-11:00': interviews['10:30-11:00'],
                   '11:00-11:30': interviews['11:00-11:30'],
                   '11:30-12:00': interviews['11:30-12:00'],
                   '12:00-12:30': interviews['12:00-12:30'],
                   '12:30-13:00': interviews['12:30-13:00'],
                   '13:00-13:30': interviews['13:00-13:30'],
                   '13:30-14:00': interviews['13:30-14:00'],
                   '14:00+': interviews['14:00+'],
                   })

df.groupby('month').sum().sort_values(by='month').plot(kind="bar", stacked=True, figsize=(20, 16))
plt.show()

# %%
df = pd.DataFrame({'weekday': waiting_time['weekday'],
                   '08:00-08:30': interviews['08:00-08:30'],
                   '08:30-09:00': interviews['08:30-09:00'],
                   '09:00-09:30': interviews['09:00-09:30'],
                   '09:30-10:00': interviews['09:30-10:00'],
                   '10:00-10:30': interviews['10:00-10:30'],
                   '10:30-11:00': interviews['10:30-11:00'],
                   '11:00-11:30': interviews['11:00-11:30'],
                   '11:30-12:00': interviews['11:30-12:00'],
                   '12:00-12:30': interviews['12:00-12:30'],
                   '12:30-13:00': interviews['12:30-13:00'],
                   '13:00-13:30': interviews['13:00-13:30'],
                   '13:30-14:00': interviews['13:30-14:00'],
                   '14:00+': interviews['14:00+'],
                   })

df.groupby('weekday').sum().sort_values(by='weekday').plot(kind="bar", figsize=(20, 16))
plt.show()

# %%
all_visits = pd.DataFrame({'date': waiting_time['date'],
                           'year': waiting_time['year'],
                           'month': waiting_time['month'],
                           'weekday': waiting_time['weekday'],
                           'all_visits_per_day': visits['visits_per_day'] + interviews['interviews_per_day'],
                           '0-5' : waiting_time['0-5'],
                           '5-10' : waiting_time['5-10'], 
                           '15-30' :  waiting_time['15-30'], 
                           '30-60' :  waiting_time['30-60'], 
                           '60+' :  waiting_time['60+']
                           })
all_visits.describe()
# Out:
#               year        month      weekday  all_visits_per_day          0-5  \
# count  1787.000000  1787.000000  1787.000000         1787.000000  1787.000000
# mean   2015.526021     6.405148     2.471181         1249.752098   307.011192
# std       1.745181     3.457847     1.693024          641.753295   155.370106
# min    2013.000000     1.000000     0.000000            5.000000     0.000000
# 25%    2014.000000     3.000000     1.000000         1039.500000   235.500000
# 50%    2016.000000     6.000000     2.000000         1302.000000   331.000000
# 75%    2017.000000     9.000000     4.000000         1582.000000   414.000000
# max    2019.000000    12.000000     5.000000         3031.000000   717.000000
#
#               5-10        15-30        30-60          60+
# count  1787.000000  1787.000000  1787.000000  1787.000000
# mean     91.821489    90.003358    49.525462    12.703414
# std      50.302779    67.549020    66.685661    28.057260
# ...

# %%
df = pd.DataFrame({'year': all_visits['year'],
                   'all_visits_per_day': all_visits['all_visits_per_day']
                   })

df.groupby('year').sum().sort_values(by='year').plot(kind="bar", stacked=True, figsize=(20, 16))
plt.show()

# %%
df = pd.DataFrame({'month': all_visits['month'],
                   'all_visits_per_day': all_visits['all_visits_per_day']
                   })

df.groupby('month').sum().sort_values(by='month').plot(kind="bar", stacked=True, figsize=(20, 16))
plt.show()

# %%
df = pd.DataFrame({'weekday': all_visits['weekday'],
                   'all_visits_per_day': all_visits['all_visits_per_day']
                   })

df.groupby('weekday').sum().sort_values(by='weekday').plot(kind="bar", stacked=True, figsize=(20, 16))
plt.show()

# %%
df = pd.DataFrame({'date': cleaned_history['date'],
                   'all_visits_per_day': all_visits['all_visits_per_day'],
                })
df.head()
# Out:
#         date  all_visits_per_day
# 0 2019-01-30                1246
# 1 2019-01-31                1205
# 2 2019-02-01                1375
# 3 2019-01-25                1159
# 4 2019-01-26                  77

# %%
df.plot(x='date', figsize=(25, 20))

# %%
over_3000 = df[df['all_visits_per_day'] > 3000]
over_3000
# Out:
#            date  all_visits_per_day
# 1507 2013-12-03                3024
# 1509 2013-12-05                3031

# %%
over_3000 = df[df['all_visits_per_day'] < 10]
over_3000
# Out:
#            date  all_visits_per_day
# 849  2016-02-20                   5
# 1496 2013-12-24                   6

# %%
df = pd.DataFrame({'weekday': cleaned_history['weekday'],
                   'all_visits_per_day': all_visits['all_visits_per_day'],
                })
df.groupby('weekday').max().plot(kind="bar", figsize=(20,16))

# %%
df = pd.DataFrame({'all_visits_per_day': all_visits['all_visits_per_day'],
                   '0-5' : waiting_time['0-5'],
                   '5-10' : waiting_time['5-10'], 
                   '15-30' :  waiting_time['15-30'], 
                   '30-60' :  waiting_time['30-60'], 
                   '60+' :  waiting_time['60+']
                })
fig = plt.figure(figsize=(20, 16))
ax = fig.add_subplot(111)
ax.scatter(df['all_visits_per_day'], df['60+'], c='r', marker='o')
ax.set_xlabel('All visits / day')
ax.set_ylabel('Visitors')
plt.show()
